# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('college_placement_dataset_final.csv')
df
# Out:
#       CGPA  Internship  Paid_Internship  Projects  Workshop_Certification  \
# 0     8.19           0                0         4                       6
# 1     7.17           0                0         3                       8
# 2     9.02           1                0         5                       7
# 3     8.44           1                0         4                       7
# 4     8.63           1                0         5                       8
# ...    ...         ...              ...       ...                     ...
# 4995  7.25           1                1         5                       7
# 4996  6.11           1                0         5                       6
# 4997  6.00           0                0         4                       8
# 4998  8.39           0                0         4                       7
# 4999  8.27           1                0         5                       6
#
#       Aptitude_Score  Skills_Rating Placement_Training  SSC_Marks  Gender  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 11 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   CGPA                    5000 non-null   float64
#  1   Internship              5000 non-null   int64
#  2   Paid_Internship         5000 non-null   int64
#  3   Projects                5000 non-null   int64
#  4   Workshop_Certification  5000 non-null   int64
#  5   Aptitude_Score          5000 non-null   float64
#  6   Skills_Rating           5000 non-null   float64
#  7   Placement_Training      5000 non-null   object
#  8   SSC_Marks               5000 non-null   float64
#  9   Gender                  5000 non-null   object
#  10  Placement_Status        5000 non-null   object
# dtypes: float64(4), int64(4), object(3)
# memory usage: 429.8+ KB

# %%
df.describe()
# Out:
#               CGPA   Internship  Paid_Internship     Projects  \
# count  5000.000000  5000.000000       5000.00000  5000.000000
# mean      7.760374     0.430000          0.10000     3.227600
# std       0.968259     0.570232          0.30003     1.370903
# min       6.000000     0.000000          0.00000     1.000000
# 25%       7.050000     0.000000          0.00000     2.000000
# 50%       7.770000     0.000000          0.00000     3.000000
# 75%       8.470000     1.000000          0.00000     4.000000
# max      10.000000     2.000000          1.00000     5.000000
#
#        Workshop_Certification  Aptitude_Score  Skills_Rating    SSC_Marks
# count             5000.000000      5000.00000    5000.000000  5000.000000
# mean                 4.887200        65.82129       6.574288    74.244382
# std                  2.504901        16.57097       1.492752     8.982829
# min                  0.000000         0.00000       1.000000    60.000000
# ...

# %%
from sklearn.preprocessing import OneHotEncoder
ohe = OneHotEncoder(drop='first', sparse_output=False)

from sklearn.preprocessing import StandardScaler
scale = StandardScaler()

from sklearn.pipeline import Pipeline

# %%
from sklearn.compose import  ColumnTransformer
preprocessor = ColumnTransformer([
    ('ohe', ohe, ['Placement_Training', 'Gender', 'Placement_Status']),
    ('scale', scale, ['CGPA','Internship','Paid_Internship','Projects','Workshop_Certification','Aptitude_Score','Skills_Rating','SSC_Marks'])
    
], remainder='passthrough')

main_preprocessing_pipeline = Pipeline(['preprocessor', preprocessor])

# %%
from sklearn.linear_model import LogisticRegression
lr = LogisticRegression()

from sklearn.tree import DecisionTreeClassifier
dt = DecisionTreeClassifier(max_depth=5)

# %%
x = df.drop(columns=['Placement_Status'])
y = df['Placement_Status']

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=.2, random_state=42)

from sklearn.metrics import accuracy_score

# %%
x_train_trf = main_preprocessing_pipeline.fit_transform(x_train, y_train)
x_test_trf = main_preprocessing_pipeline.transform(x_test)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[281], line 1
# ----> 1 x_train_trf = main_preprocessing_pipeline.fit_transform(x_train, y_train)
#       2 x_test_trf = main_preprocessing_pipeline.transform(x_test)
#
# File ~/anaconda3/lib/python3.12/site-packages/sklearn/utils/_available_if.py:43, in _AvailableIfDescriptor.__get__(self, obj, owner)
#      39 def __get__(self, obj, owner=None):
#      40     if obj is not None:
#      41         # delegate only on instances, not the classes.
#      42         # this is to allow access to the docstrings.
# ---> 43         self._check(obj, owner=owner)
#      44         out = MethodType(self.fn, obj)
#      46     else:
#      47         # This makes it possible to use the decorated method as an unbound method,
#      48         # for instance when monkeypatching.
#
# ...
